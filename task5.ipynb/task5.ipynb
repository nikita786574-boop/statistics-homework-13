# %%
from scipy.stats import chi2

# Первым аргументом функции передаём уровень значимости альфа

print(chi2.ppf(0.05, df = 29))
print(chi2.ppf(0.95, df=29))

chi2_2 = chi2.ppf(0.05, df = 29)
chi2_1 = chi2.ppf(0.95, df = 29)
s = 2
n = 30
print(chi2_1, chi2_2)

print(f"[{round((n-1)*s**2 / chi2_1, 4)} ; {round((n-1)*s**2/chi2_2, 4)}]")
# Out:
# 17.708366182824584
# 42.55696780429269
# 42.55696780429269 17.708366182824584
# [2.7258 ; 6.5506]
